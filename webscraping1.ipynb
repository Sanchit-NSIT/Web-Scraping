# %%
import urllib.request
from bs4 import BeautifulSoup
import csv


# specify the url
urlpage =  'http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/' 
print(urlpage)
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find results within table
table = soup.find('table', attrs={'class': 'tableSorter'})
results = table.find_all('tr')
print('Number of results', len(results))

# create and write headers to a list 
rows = []
rows.append(['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'])

# loop over results
for result in results:
    # find all columns per result
    data = result.find_all('td')
    # check that columns have data 
    if len(data) == 0: 
        continue
    
    # write columns to variables
    rank = data[0].getText()
    company = data[1].getText()
    location = data[2].getText()
    yearend = data[3].getText()
    salesrise = data[4].getText()
    sales = data[5].getText()
    staff = data[6].getText()
    comments = data[7].getText()
    
    # print('Company is', company)
    # Company is WonderblyPersonalised children's books
    # print('Sales', sales)
    # Sales *25,860

    # extract description from the name
    companyname = data[1].find('span', attrs={'class':'company-name'}).getText()    
    description = company.replace(companyname, '')
    
    # remove unwanted characters
    sales = sales.strip('*').strip('†').replace(',','')
    
    # go to link and extract company website
    url = data[1].find('a').get('href')
    page = urllib.request.urlopen(url)
    # parse the html using beautiful soup and store in variable 'soup'
    soup = BeautifulSoup(page, 'html.parser')
    # find the last result in the table and get the link
    try:
        tableRow = soup.find('table').find_all('tr')[-1]
        webpage = tableRow.find('a').get('href')
    except:
        webpage = None
    
    # write each result to rows
    rows.append([rank, companyname, webpage, description, location, yearend, salesrise, sales, staff, comments])


print(rows)
# Out:
# http://www.fasttrack.co.uk/league-tables/tech-track-100/league-table/
# Number of results 101
# [['Rank', 'Company Name', 'Webpage', 'Description', 'Location', 'Year end', 'Annual sales rise over 3 years', 'Sales £000s', 'Staff', 'Comments'], ['1', 'Plan.com', 'http://www.plan.com', 'Communications provider', 'Isle of Man', 'Sep-17', '364.38%', '35418', '90', 'About 650 partners use its telecoms platform to support more than 100,000 UK business customers'], ['2', 'PsiOxus', 'http://www.psioxus.com', 'Biotechnology developer', 'Oxfordshire', 'Dec-17', '311.67%', '53136', '54', 'Received a $15m milestone payment from its development partner Bristol-Myers Squibb in December'], ['3', 'CensorNet', 'http://www.censornet.com', 'Cloud security software developer', 'Basingstoke', 'Dec-17', '210.17%', '7535', '77', 'Has more than 4,000 customers, including McDonald’s in France and the European Central Bank'], ['4', 'thoughtonomy', 'http://www.thoughtonomy.com', 'Automation software developer', 'East London', 'May-18', '205.20%', '16916', '100', 'It sells to 28 countries and 50% of revenue is generated from overseas'], ['5', 'Perkbox', 'http://www.perkbox.com', 'Employee engagement services', 'Central London', 'Dec-17', '204.12%', '34700', '200', 'Acquired software platform Loyalty Bay for an undisclosed sum in November'], ['6', 'Ogury', 'http://www.ogury.com', 'Mobile data marketing', 'North London', 'Dec-17', '204.09%', '33760', '133', 'It has access to data from more than 400m mobile phone users in 120 countries'], ['7', 'Verve', 'http://www.verve.co', 'Marketing software developer', 'Central London', 'Dec-17', '202.15%', '10747', '130', 'Its network of 25,000 ‘micro-influencers’ have sold half a million event tickets since 2014'], ['8', 'goHenry', 'http://www.gohenry.co.uk', "Children's pre-paid card developer", 'Central London', 'Dec-17', '200.87%', '6116', '61', 'The company is named after the first child to make a transaction with one of its cards'], ['9', 'Darktrace', 'http://www.darktrace.com', 'Cybersecurity developer', 'Cambridge', 'Jun-18', '195.51%', '58573', '694', 'Was reportedly valued at $1.25bn in April when Vitruvian Partners bought a small stake'], ['10', 'Bizuma', 'http://www.bizuma.com', 'B2B e-commerce platform', 'Central London', 'Mar-18', '181.75%', '9608', '48', 'Originally founded as a flash sales website before changing direction in 2014'], ['11', 'Depop', 'http://www.depop.com', 'Social shopping app', 'Central London', 'Dec-17', '175.70%', '94300', '95', 'More than 10m people use its platform to buy and sell vintage clothing'], ['12', 'Laser Wire Solutions', 'http://www.laserwiresolutions.com', 'Laser wire-stripping machinery', 'Pontypridd', 'Dec-17', '173.41%', '5114', '26', 'Swiss technology group Schleuniger took a 20% stake in 2016'], ['13', 'Bought By Many', 'http://www.boughtbymany.com', 'Specialist insurance platform', 'Central London', 'Mar-18', '170.20%', '19727', '78', 'Launched its own travel insurance policy for people with severe medical conditions in December'], ['14', 'Optal', 'http://www.optal.com', 'Payment services provider', 'Central London', 'Dec-17', '169.29%', '177653', '65', 'Uses the Mastercard processing network to facilitate payments in 34 currencies'], ['15', 'Infinox', 'http://www.infinox.com', 'Currency trading platform', 'Central London', 'Mar-18', '155.18%', '41700', '48', 'Provides users with an AI-generated news feed that could affect currency trades'], ['16', 'Oakbrook', 'http://www.oakbrookfinance.com', 'Consumer finance provider', 'Nottingham', 'Dec-17', '154.54%', '40400', '98', 'Uses machine learning to help estimate borrowers’ credit risk'], ['17', 'Carwow', 'http://www.carwow.co.uk', 'Car sales platform', 'Central London', 'Dec-17', '147.21%', '15276', '127', 'Claims its car review videos have more viewers than the hit BBC series Top Gear'], ['18', 'Receipt Bank', 'http://www.receipt-bank.com', 'Book-keeping automation services', 'Central London', 'Dec-17', '146.07%', '11667', '341', 'Says 150,000 businesses in America, Europe and Australia use its book-keeping so ...

# %%
import pandas as pd
import numpy as np
arr=np.array(rows)
df=pd.DataFrame(arr[1:],columns=arr[0])
df
# Out:
#    Rank                Company Name                             Webpage  \
# 0     1                    Plan.com                 http://www.plan.com
# 1     2                     PsiOxus              http://www.psioxus.com
# 2     3                   CensorNet            http://www.censornet.com
# 3     4                thoughtonomy         http://www.thoughtonomy.com
# 4     5                     Perkbox              http://www.perkbox.com
# 5     6                       Ogury                http://www.ogury.com
# 6     7                       Verve                 http://www.verve.co
# 7     8                     goHenry            http://www.gohenry.co.uk
# 8     9                   Darktrace            http://www.darktrace.com
# 9    10                      Bizuma               http://www.bizuma.com
# 10   11                       Depop                http://www.depop.com
# 11   12        Laser Wire Solutions   http://www.laserwiresolutions.com
# 12   13              Bought By Many         http://www.boughtbymany.com
# 13   14                       Optal                http://www.optal.com
# 14   15                     Infinox              http://www.infinox.com
# 15   16                    Oakbrook      http://www.oakbrookfinance.com
# 16   17                      Carwow             http://www.carwow.co.uk
# 17   18                Receipt Bank         http://www.receipt-bank.com
# 18   19                dB Broadcast        http://www.dbbroadcast.co.uk
# 19   20        The Car Buying Group  http://www.thecarbuyinggroup.co.uk
# 20   21                   Festicket            http://www.festicket.com
# 21   22                     Planixs              http://www.planixs.com
# 22   23                   Gigaclear            http://www.gigaclear.com
# 23   24                TransferWise         http://www.transferwise.com
# 24   25                     PatSnap              http://www.patsnap.com
# 25   26                  Hyperoptic           http://www.hyperoptic.com
# 26   27                  GoCardless           http://www.gocardless.com
# 27   28                      Purple                http://www.purple.ai
# 28   29             Trustpay Global       http://www.trustpayglobal.com
# 29   30                       iwoca              http://www.iwoca.co.uk
# ..  ...                         ...                                 ...
# 70   71         Love Energy Savings    http://www.loveenergysavings.com
# 71   72            Creative Virtual      http://www.creativevirtual.com
# 72   73                       Ebury        http://www.eburypartners.com
# 73   74                  ZappiStore           http://www.zappistore.com
# 74   75                        Blis                 http://www.blis.com
# 75   76                  BookingBug         http://www.bookingbug.co.uk
# 76   77                      Egress               http://www.egress.com
# 77   78                Contis Group          http://www.contisgroup.com
# 78   79                  PM Connect          http://www.pmconnect.co.uk
# 79   80                        Zopa                 http://www.zopa.com
# 80   81                  WorldRemit           http://www.worldremit.com
# 81   82                     Dianomi              http://www.dianomi.com
# 82   83                     Liberis            http://www.liberis.co.uk
# 83   84               Currencycloud     http://www.thecurrencycloud.com
# 84   85                Featurespace       http://www.featurespace.co.uk
# 85   86  Cloud Technology Solutions     http://www.cloudsolutions.co.uk
# 86   87          Leisure Pass Group     http://www.leisurepassgroup.com
# 87   88                      rradar               http://www.rradar.com
# 88   89                 Converge TS                http://www.cts.co.uk
# 89   90         Kimble Applications           http://www.kimbleapps.com
# 90   91                Paymentsense       http://www.paymentsense.co.uk
# 91   92          Godel Technologies            http://www.godeltech.com
# 92   93              Secret Escapes        http://www.secretescapes.com
# 93   94                      Neuven             http://www.neuven.co.uk
# 94   95                      CitNOW               http://www.citnow.com
# 95   96                         geo          http://www.geotogether.com
# 96   97                   Vision RT             http://www.visionrt.com
# 97   98                      Thread               http://www.thread.com
# 98   99             The Media Image      http://www.the-media-image.com
# 99  100         Brompton Technology         http://www.bromptontech.com
#
#                            Description         Location Year end  \
# 0              Communications provider      Isle of Man   Sep-17
# 1              Biotechnology developer      Oxfordshire   Dec-17
# 2    Cloud security software developer      Basingstoke   Dec-17
# 3        Automation software developer      East London   May-18
# 4         Employee engagement services   Central London   Dec-17
# 5                Mobile data marketing     North London   Dec-17
# 6         Marketing software developer   Central London   Dec-17
# 7   Children's pre-paid card developer   Central London   Dec-17
# 8              Cybersecurity developer        Cambridge   Jun-18
# 9              B2B e-commerce platform   Central London   Mar-18
# 10                 Social shopping app   Central London   Dec-17
# 11      Laser wire-stripping machinery       Pontypridd   Dec-17
# 12       Specialist insurance platform   Central London   Mar-18
# 13           Payment services provider   Central London   Dec-17
# 14           Currency trading platform   Central London   Mar-18
# 15           Consumer finance provider       Nottingham   Dec-17
# 16                  Car sales platform   Central London   Dec-17
# 17    Book-keeping automation services   Central London   Dec-17
# 18       Broadcast technology provider   Cambridgeshire   Sep-17
# 19                  Car sales platform        Wakefield   Mar-18
# 20           Festival booking platform   Central London   Dec-17
# 21                  Software developer       Manchester   Mar-17
# 22          Internet services provider      Oxfordshire   Dec-17
# 23          Currency transfer provider      East London   Mar-18
# 24                   R&D data platform      West London   Dec-17
# 25          Internet services provider      West London   Dec-17
# 26           Payment services provider   Central London   Dec-17
# 27              Wifi services provider           Oldham   Jan-18
# 28             Online payment provider        Guildford   Mar-18
# 29           Business finance provider   Central London   Dec-17
# ..                                 ...              ...      ...
# 70            Price comparison website           Bolton   Dec-17
# 71                   Chatbot developer      East London   Dec-17
# 72           Business finance provider   Central London   Apr-18
# 73          Research services provider   Central London   Dec-17
# 74            Location data technology   Central London   Dec-17
# 75           Booking systems developer   Central London   Mar-18
# 76              Data security provider   Central London   Dec-17
# 77           Payment services provider  North Yorkshire   Mar-17
# 78             Mobile content provider       Birmingham   Feb-18
# 79       Peer-to-peer lending platform     South London   Dec-17
# 80              Online money transfers   Central London   Dec-17
# 81         Financial content marketing   Central London   Dec-17
# 82               Cash advance provider      West London   Dec-17
# 83           Payment services provider      East London   Dec-17
# 84        Analytics software developer        Cambridge   Dec-17
# 85                  Cloud IT developer       Manchester   Mar-18
# 86         Tourism smartcard developer   Central London   Dec-17
# 87              Legal digital services             Hull   Dec-17
# 88             Cloud services provider         Cheshire   Dec-17
# 89                  Software developer   Central London   Dec-17
# 90           Payment services provider      West London   Mar-18
# 91                  Software developer       Manchester   Dec-17
# 92              Online travel services   Central London   Dec-17
# 93               HR software developer       Manchester   Jul-17
# 94            Video software developer        Wokingham   Dec-17
# 95             Smart energy monitoring        Cambridge   Mar-18
# 96        Medical technology developer     North London   Jul-17
# 97             Online fashion services   Central London   Dec-17
# 98            Digital marketing agency     South London   Feb-18
# 99           Video technology provider      West London   Aug-17
#
#    Annual sales rise over 3 years Sales £000s Staff  \
# 0                         364.38%       35418    90
# 1                         311.67%       53136    54
# 2                         210.17%        7535    77
# 3                         205.20%       16916   100
# 4                         204.12%       34700   200
# 5                         204.09%       33760   133
# 6                         202.15%       10747   130
# 7                         200.87%        6116    61
# 8                         195.51%       58573   694
# 9                         181.75%        9608    48
# 10                        175.70%       94300    95
# 11                        173.41%        5114    26
# 12                        170.20%       19727    78
# 13                        169.29%      177653    65
# 14                        155.18%       41700    48
# 15                        154.54%       40400    98
# 16                        147.21%       15276   127
# 17                        146.07%       11667   341
# 18                        143.58%       34943    50
# 19                        140.89%       39140    31
# 20                        139.86%       35839    88
# 21                        133.70%        7240    67
# 22                        130.17%        7402   210
# 23                        129.39%      117283  1000
# 24                        126.18%       17977   752
# 25                        119.90%       16572   411
# 26                        112.99%       11896   165
# 27                        112.88%        5586    93
# 28                        110.45%        9796    25
# 29                        109.27%       25000   200
# ..                            ...         ...   ...
# 70                         64.26%       17361   183
# 71                         63.30%        8400    99
# 72                         62.77%       47000   628
# 73                         61.62%       19323   128
# 74                         61.28%       33400   186
# 75                         60.61%        6937   117
# 76                         60.22%        9403   115
# 77                         59.56%        7161    86
# 78                         59.44%       19317    35
# 79                         59.43%       46500   312
# 80                         59.07%       61000   440
# 81                         58.99%       12861    25
# 82                         57.99%       15150    75
# 83                         57.48%       13600   140
# 84                         57.48%        5170   113
# 85                         57.21%       21902   102
# 86                         57.16%      225803   105
# 87                         57.03%        5083   125
# 88                         55.00%        5802    38
# 89                         54.67%        9153    78
# 90                         53.54%       72400   243
# 91                         53.01%       13853   637
# 92                         52.99%       73000   850
# 93                         52.23%      130071    28
# 94                         51.85%       11611    71
# 95                         51.24%       29406    85
# 96                         50.99%       32468   132
# 97                         50.77%        6492    60
# 98                         50.38%       27515    37
# 99                         50.17%        5250    27
#
#                                              Comments
# 0   About 650 partners use its telecoms platform t...
# 1   Received a $15m milestone payment from its dev...
# 2   Has more than 4,000 customers, including McDon...
# 3   It sells to 28 countries and 50% of revenue is...
# 4   Acquired software platform Loyalty Bay for an ...
# 5   It has access to data from more than 400m mobi...
# 6   Its network of 25,000 ‘micro-influencers’ have...
# 7   The company is named after the first child to ...
# 8   Was reportedly valued at $1.25bn in April when...
# 9   Originally founded as a flash sales website be...
# 10  More than 10m people use its platform to buy a...
# 11  Swiss technology group Schleuniger took a 20% ...
# 12  Launched its own travel insurance policy for p...
# 13  Uses the Mastercard processing network to faci...
# 14  Provides users with an AI-generated news feed ...
# 15  Uses machine learning to help estimate borrowe...
# 16  Claims its car review videos have more viewers...
# 17  Says 150,000 businesses in America, Europe and...
# 18  Its key customers include Sky, YouTube, Bloomb...
# 19  Runs a free nationwide doorstep vehicle collec...
# 20  Sells tickets and packages to more than 1,000 ...
# 21  More than £200bn worth of transactions have be...
# 22  Has connected more than 16,000 rural customers...
# 23  Was valued at $1.6bn in November after it rais...
# 24  Has raised more than $100m from investors incl...
# 25  Aims to provide superfast broadband to more th...
# 26  International expansion plans include targetin...
# 27  Its technology is used in every public airport...
# 28  The Premier Lotto in Nigeria uses the company’...
# 29   Its 140 employees include three former Olympians
# ..                                                ...
# 70  Has helped 145,000 UK homes and businesses sav...
# 71  Its trademarked chatbot can be used through Fa...
# 72  Has traded £12.5bn in foreign exchange in 140 ...
# 73  Holds weekly hackathons with its clients and p...
# 74      Analyses more than 5.5bn data points each day
# 75  Raised nearly £10m in April from backers inclu...
# 76  Users of its platform can revoke access to ema...
# 77  Appointed the former European boss of American...
# 78  Its clients include World Wrestling Entertainm...
# 79  About £3.5bn has been advanced through its pla...
# 80  Has raised $220m since 2010 to expand its onli...
# 81  Works with eight of the top 10 global asset ma...
# 82  Received £57.5m in funding in April from inves...
# 83  Has 250 clients and 2m end users across the world
# 84  Is recruiting for more than 100 positions this...
# 85  Its software has moved nearly 12,000 companies...
# 86  Has partnered with the booking platform Ctrip ...
# 87  Uses machine learning and AI to provide legal ...
# 88  Focused solely on the legal sector after its f...
# 89  More than half of its new business is in the U...
# 90  Processed more than £6.5bn of card payments la...
# 91  Is named after the late German mathematician K...
# 92  Has raised £132m from investors including Goog...
# 93  Appearing on Tech Track 100 for a fourth conse...
# 94  Has more than 8,000 installations in franchise...
# 95  Customers in Norway, Sweden and Luxembourg use...
# 96  Has secured 60 patents and has another 46 pending
# 97  More than 800,000 men subscribe to its free pe...
# 98  Founded by the man who was Google UK’s first r...
# 99  Its technology is used in high-profile events ...
#
# [100 rows x 10 columns]
